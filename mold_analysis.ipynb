# %%
## import pandas 
import pandas as pd

# %%
## import dataset
df = pd.read_csv('NYCHA-mold-violations.csv')
df
# Out:
#      Violation ID  Primary Building Identifier  Primary Boro Identifier  \
# 0        18223816                       286990                        3
# 1        18311210                       804658                        1
# 2        18259184                       806350                        2
# 3        18235897                       806350                        2
# 4        18235898                       806350                        2
# ..            ...                          ...                      ...
# 104      18652131                       120460                        2
# 105      18654935                       847216                        3
# 106      18662256                       972853                        1
# 107      18635496                       808526                        3
# 108      18639299                       807814                        3
#
#     Primary Borough Name Primary House Number Primary Low House Number  \
# ...

# %%
df.head()
# Out:
#    Violation ID  Primary Building Identifier  Primary Boro Identifier  \
# 0      18223816                       286990                        3
# 1      18311210                       804658                        1
# 2      18259184                       806350                        2
# 3      18235897                       806350                        2
# 4      18235898                       806350                        2
#
#   Primary Borough Name Primary House Number Primary Low House Number  \
# 0             BROOKLYN                  621                      615
# 1            MANHATTAN                  218                      218
# 2                BRONX                 1815                     1815
# 3                BRONX                 1815                     1815
# 4                BRONX                 1815                     1815
#
#   Primary High House Number Primary Street Name  Primary Postcode  \
# ...

# %%
df.tail()
# Out:
#      Violation ID  Primary Building Identifier  Primary Boro Identifier  \
# 104      18652131                       120460                        2
# 105      18654935                       847216                        3
# 106      18662256                       972853                        1
# 107      18635496                       808526                        3
# 108      18639299                       807814                        3
#
#     Primary Borough Name Primary House Number Primary Low House Number  \
# 104                BRONX                 1320                     1318
# 105             BROOKLYN                  542                      542
# 106            MANHATTAN                 3150                     3140
# 107             BROOKLYN                  811                      811
# 108             BROOKLYN                  198                      198
#
#     Primary High House Number Primary Street Name  Primary Postcode  \
# ...

# %%
df.sample(10)
# Out:
#     Violation ID  Primary Building Identifier  Primary Boro Identifier  \
# 85      18510185                       811708                        4
# 96      18654928                       847216                        3
# 54      18327315                       809517                        3
# 81      18531647                       804695                        1
# 66      18601457                       808427                        3
# 76      18539056                       804634                        1
# 61      18334539                       806882                        2
# 47      18342646                       806051                        1
# 58      18370705                       807996                        3
# 0       18223816                       286990                        3
#
#    Primary Borough Name Primary House Number Primary Low House Number  \
# 85               QUEENS               116-40                   116-40
# ...

# %%
## How many violations are there in total? 
len(df)
# Out:
# 109

# %%
## How many violations are there per borough? 
df["Primary Borough Name"].value_counts()
# Out:
# Primary Borough Name
# BROOKLYN         45
# MANHATTAN        44
# BRONX            13
# QUEENS            6
# STATEN ISLAND     1
# Name: count, dtype: int64

# %%
## Which developments have the most violations? 
df["Development Name"].value_counts()
# Out:
# Development Name
# RED HOOK WEST                         10
# RED HOOK EAST                          7
# JOHNSON                                6
# SOTOMAYOR HOUSES                       4
# WAGNER                                 4
# FARRAGUT                               4
# ALBANY                                 4
# VLADECK                                3
# SHEEPSHEAD BAY                         3
# WSUR (SITE A) 120 WEST 94TH STREET     3
# VAN DYKE I                             3
# WALD                                   3
# MARCY                                  3
# JEFFERSON                              2
# BUTLER                                 2
# DOUGLASS I                             2
# CORSI HOUSES                           2
# EAST RIVER                             2
# BLAND                                  2
# WSUR (BROWNSTONES)                     2
# CONEY ISLAND I (SITES 4 & 5)           2
# SAINT NICHOLAS                         2
# ...

# %%
## How recent is the data?
df[['Inspection Date', 'Development Name']]
# Out:
#     Inspection Date  Development Name
# 0        09/12/2025         BREUKELEN
# 1        10/20/2025         JEFFERSON
# 2        09/18/2025  SOTOMAYOR HOUSES
# 3        09/18/2025  SOTOMAYOR HOUSES
# 4        09/18/2025  SOTOMAYOR HOUSES
# ..              ...               ...
# 104      02/18/2026            BUTLER
# 105      02/19/2026             MARCY
# 106      02/24/2026             GRANT
# 107      02/11/2026     RED HOOK EAST
# 108      02/12/2026           GOWANUS
#
# [109 rows x 2 columns]

# %%
## Converting to datetime
df['Inspection Date'] = pd.to_datetime(df['Inspection Date'], errors='coerce')
df
# Out:
#      Violation ID  Primary Building Identifier  Primary Boro Identifier  \
# 0        18223816                       286990                        3
# 1        18311210                       804658                        1
# 2        18259184                       806350                        2
# 3        18235897                       806350                        2
# 4        18235898                       806350                        2
# ..            ...                          ...                      ...
# 104      18652131                       120460                        2
# 105      18654935                       847216                        3
# 106      18662256                       972853                        1
# 107      18635496                       808526                        3
# 108      18639299                       807814                        3
#
#     Primary Borough Name Primary House Number Primary Low House Number  \
# ...

# %%
## Only looking at violatoins for 2026 
df_2026 = df[df['Inspection Date'].dt.year == 2026]

# %%
## Violations in 2026 by development 
df_2026["Development Name"].value_counts()
# Out:
# Development Name
# FARRAGUT                        3
# MARCY                           3
# JOHNSON                         3
# ATLANTIC TERMINAL SITE 4B       2
# RIIS II                         2
# WALD                            2
# ASTORIA                         2
# GRANT                           2
# WAGNER                          2
# RED HOOK EAST                   2
# GLENWOOD                        1
# CONEY ISLAND I (SITES 4 & 5)    1
# SMITH                           1
# CAREY GARDENS                   1
# DOUGLASS I                      1
# LEXINGTON                       1
# RED HOOK WEST                   1
# BUTLER                          1
# GOWANUS                         1
# Name: count, dtype: int64

# %%
## Only looking at violations for 2025 
df_2025 = df[df['Inspection Date'].dt.year == 2025]

# %%
df_2025["Development Name"].value_counts()
# Out:
# Development Name
# RED HOOK WEST                         9
# RED HOOK EAST                         5
# SOTOMAYOR HOUSES                      4
# ALBANY                                4
# VLADECK                               3
# JOHNSON                               3
# SHEEPSHEAD BAY                        3
# WSUR (SITE A) 120 WEST 94TH STREET    3
# VAN DYKE I                            3
# JEFFERSON                             2
# CORSI HOUSES                          2
# EAST RIVER                            2
# BLAND                                 2
# WSUR (BROWNSTONES)                    2
# WAGNER                                2
# SAINT NICHOLAS                        2
# CASTLE HILL                           2
# BAISLEY PARK                          2
# BREUKELEN                             1
# BUTLER                                1
# RIIS                                  1
# MORRIS I                              1
# GLENMORE PLAZA                        1
# ...
